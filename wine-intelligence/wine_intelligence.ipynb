# %% [markdown]
# # Qualio — Wine Intelligence
# ### Advanced Machine Learning · Final Project
#
# **Dataset:** WineSensed — Learning to Taste, NeurIPS 2023
# **Models:** CNN (ResNet-18) for wine style classification + BiLSTM for quality tier prediction
# **Integration:** Combined sourcing recommendation with napping-based taste similarity
#
# ---

# %% [markdown]
# ## Cell 1 — Install dependencies
# Run this cell once. All packages needed for the entire notebook.

# %%
# Cell 1 — Workstation setup
# Run once. Installs everything the notebook needs.

# %pip install torch torchvision --index-url https://download.pytorch.org/whl/cpu
# %pip install datasets transformers
# %pip install pandas numpy matplotlib seaborn scikit-learn
# %pip install torchcam
# %pip install streamlit
# %pip install Pillow tqdm

# %% [markdown]
# ## Cell 2 — Imports
# Import all libraries used throughout the notebook.

# %%
# Cell 2 — Imports

import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image
from tqdm import tqdm

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
import torchvision
import torchvision.transforms as transforms
from torchvision import models

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, ConfusionMatrixDisplay

# Reproducibility
SEED = 42
torch.manual_seed(SEED)
np.random.seed(SEED)

# Device — uses GPU if available, otherwise CPU
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'Using device: {DEVICE}')

# %% [markdown]
# ---
# ## STEP 1 — Load the dataset (sanity check first)
# > Before any training, verify the data loaded correctly and check file sizes.

# %%
# Cell 3 — Dataset size check (run before anything else)
# TODO: fill in after downloading the WineSensed small split from HuggingFace

from datasets import load_dataset

print('Loading WineSensed small split...')
dataset = load_dataset('Dakhoo/L2T-NeurIPS-2023', split='train[:5%]')  # small sample for Phase 1

print(f'Number of samples: {len(dataset)}')
print(f'Columns: {dataset.column_names}')
print('\nFirst row:')
print(dataset[0])
